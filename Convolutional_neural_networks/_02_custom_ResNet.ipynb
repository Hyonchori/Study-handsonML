# %% [markdown]
# # 케라스를 사용해 ResNet-34 구현하기

# %%
import tensorflow as tf
from tensorflow import keras

# %%
class ResidualUnit(keras.layers.Layer):
    def __init__(self, filters, strides=1, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.main_layers = [
            keras.layers.Conv2D(filters, 3, strides=strides, padding="same", use_bias=False),
            keras.layers.BatchNormalization(),
            self.activation,
            keras.layers.Conv2D(filters, 3, strides=1, padding="same", use_bias=False),
            keras.layers.BatchNormalization()
        ]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                keras.layers.Conv2D(filters, 1, strides=strides, padding="same", use_bias=False),
                keras.layers.BatchNormalization()
            ]
            
    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        
        return self.activation(Z + skip_Z)

# %% [markdown]
# **Residual unit** 만들기
# - 먼저 생성자에서 필요한 층을 모두 만듦.
# - **call** 메서드에서 입력을 main_layer와 skip_layer에 통과시킨 후 두 출력을 더하여 활성 함수를 적용한다.

# %% [markdown]
# ---

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(64, 7, strides=2, input_shape=[224, 224, 3],
                             padding="same", use_bias=False))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Activation("relu"))
model.add(keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same"))

prev_filters = 64
for filters in [64]*3 + [128]*4 + [256]*6 + [512]*3:
    strides = 1 if filters==prev_filters else 2
    model.add(ResidualUnit(filters, strides=strides))
    prev_filters = filters
    print(prev_filters)

model.add(keras.layers.GlobalAveragePooling2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(10, activation="softmax"))
# Out:
# 64
# 64
# 64
# 128
# 128
# 128
# 128
# 256
# 256
# 256
# 256
# 256
# 256
# 512
# 512
# 512

# %% [markdown]
# ---
# ## 사전학습된 ResNet

# %%
pretrained_model = keras.applications.resnet50.ResNet50(weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 5s 0us/step

# %%
from pprint import pprint

for layer in pretrained_model.layers:
    print("")
    pprint(layer.get_config())
    print(layer.trainable)
# Out:
# {'batch_input_shape': (None, 224, 224, 3),
#  'dtype': 'float32',
#  'name': 'input_1',
#  'ragged': False,
#  'sparse': False}
# True
#
# {'data_format': 'channels_last',
#  'dtype': 'float32',
#  'name': 'conv1_pad',
#  'padding': ((3, 3), (3, 3)),
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (7, 7),
#  'name': 'conv1_conv',
#  'padding': 'valid',
#  'strides': (2, 2),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv1_relu',
#  'trainable': True}
# True
#
# {'data_format': 'channels_last',
#  'dtype': 'float32',
#  'name': 'pool1_pad',
#  'padding': ((1, 1), (1, 1)),
#  'trainable': True}
# True
#
# {'data_format': 'channels_last',
#  'dtype': 'float32',
#  'name': 'pool1_pool',
#  'padding': 'valid',
#  'pool_size': (3, 3),
#  'strides': (2, 2),
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv2_block1_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block1_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block1_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv2_block1_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block1_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block1_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv2_block1_0_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv2_block1_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block1_0_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block1_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv2_block1_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block1_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv2_block2_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block2_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block2_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv2_block2_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block2_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block2_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv2_block2_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block2_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv2_block2_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block2_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv2_block3_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block3_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block3_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 64,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv2_block3_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block3_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block3_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv2_block3_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv2_block3_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv2_block3_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv2_block3_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block1_1_conv',
#  'padding': 'valid',
#  'strides': (2, 2),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block1_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block1_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv3_block1_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block1_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block1_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block1_0_conv',
#  'padding': 'valid',
#  'strides': (2, 2),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block1_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block1_0_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block1_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv3_block1_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block1_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block2_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block2_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block2_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv3_block2_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block2_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block2_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block2_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block2_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv3_block2_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block2_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block3_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block3_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block3_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv3_block3_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block3_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block3_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block3_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block3_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv3_block3_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block3_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block4_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block4_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block4_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 128,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv3_block4_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block4_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block4_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv3_block4_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv3_block4_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv3_block4_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv3_block4_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block1_1_conv',
#  'padding': 'valid',
#  'strides': (2, 2),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block1_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block1_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv4_block1_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block1_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block1_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 1024,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block1_0_conv',
#  'padding': 'valid',
#  'strides': (2, 2),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 1024,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block1_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block1_0_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block1_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv4_block1_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block1_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block2_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block2_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block2_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv4_block2_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block2_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block2_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 1024,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block2_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block2_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv4_block2_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block2_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block3_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block3_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block3_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv4_block3_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block3_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block3_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 1024,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block3_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block3_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv4_block3_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block3_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block4_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block4_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block4_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv4_block4_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block4_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block4_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 1024,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block4_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block4_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv4_block4_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block4_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block5_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block5_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block5_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
# ...
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block6_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block6_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 256,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv4_block6_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block6_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block6_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 1024,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv4_block6_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv4_block6_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv4_block6_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv4_block6_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv5_block1_1_conv',
#  'padding': 'valid',
#  'strides': (2, 2),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block1_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block1_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv5_block1_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block1_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block1_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 2048,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv5_block1_0_conv',
#  'padding': 'valid',
#  'strides': (2, 2),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 2048,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv5_block1_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block1_0_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block1_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv5_block1_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block1_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv5_block2_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block2_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block2_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv5_block2_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block2_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block2_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 2048,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv5_block2_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block2_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv5_block2_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block2_out',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv5_block3_1_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block3_1_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block3_1_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 512,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (3, 3),
#  'name': 'conv5_block3_2_conv',
#  'padding': 'same',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block3_2_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block3_2_relu',
#  'trainable': True}
# True
#
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'data_format': 'channels_last',
#  'dilation_rate': (1, 1),
#  'dtype': 'float32',
#  'filters': 2048,
#  'groups': 1,
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'kernel_size': (1, 1),
#  'name': 'conv5_block3_3_conv',
#  'padding': 'valid',
#  'strides': (1, 1),
#  'trainable': True,
#  'use_bias': True}
# True
#
# {'axis': ListWrapper([3]),
#  'beta_constraint': None,
#  'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#  'beta_regularizer': None,
#  'center': True,
#  'dtype': 'float32',
#  'epsilon': 1.001e-05,
#  'gamma_constraint': None,
#  'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#  'gamma_regularizer': None,
#  'momentum': 0.99,
#  'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#  'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#  'name': 'conv5_block3_3_bn',
#  'scale': True,
#  'trainable': True}
# True
#
# {'dtype': 'float32', 'name': 'conv5_block3_add', 'trainable': True}
# True
#
# {'activation': 'relu',
#  'dtype': 'float32',
#  'name': 'conv5_block3_out',
#  'trainable': True}
# True
#
# {'data_format': 'channels_last',
#  'dtype': 'float32',
#  'name': 'avg_pool',
#  'trainable': True}
# True
#
# {'activation': 'softmax',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'bias_regularizer': None,
#  'dtype': 'float32',
#  'kernel_constraint': None,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#                         'config': {'seed': None}},
#  'kernel_regularizer': None,
#  'name': 'predictions',
#  'trainable': True,
#  'units': 1000,
#  'use_bias': True}
# True
